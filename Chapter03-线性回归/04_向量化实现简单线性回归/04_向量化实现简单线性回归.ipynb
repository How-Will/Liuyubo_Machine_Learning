# %% [markdown]
# ## 为什么要使用向量化实现？
#
# 对比上一节使用for循环计算参数a和b。使用向量化计算可以提升性能。
#
# 通过观察可以发现参数a的分母和分子都可以写成两个向量做点乘的形式。
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1., 2., 3., 4., 5.])
y = np.array([1., 3., 2., 3., 5.])

from playML.SimpleLinearRegression import SimpleLinearRegression1

reg1 = SimpleLinearRegression1()
reg1.fit(x, y)  # 训练

y_hat1 = reg1.predict(x) # 预测

# %%
plt.scatter(x, y)
plt.plot(x, y_hat1, color = 'r')
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ## 向量化实现

# %%
from playML.SimpleLinearRegression import SimpleLinearRegression2

reg2 = SimpleLinearRegression2()
reg2.fit(x, y)
# Out:
# SimpleLinearRegression2()

# %%
reg2.a_, reg2.b_
# Out:
# (0.8, 0.39999999999999947)

# %%
y_hat2 = reg2.predict(x)
plt.scatter(x, y)
plt.plot(x, y_hat2, color = 'r')
plt.axis([0, 6, 0, 6])
plt.show()

# %% [markdown]
# ## 性能测试

# %%
m = 100000
big_x = np.random.random(size = m)
big_y = big_x * 2 + 3 + np.random.normal(size = m)

# %timeit reg1.fit(big_x, big_y)
# %timeit reg2.fit(big_x, big_y)
# Out:
# 70 ms ± 385 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 251 µs ± 4.99 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
reg1.a_, reg1.b_
# Out:
# (2.0038054573348596, 2.998794975116497)

# %%
reg2.a_, reg2.b_
# Out:
# (2.003805457334854, 2.9987949751164997)
